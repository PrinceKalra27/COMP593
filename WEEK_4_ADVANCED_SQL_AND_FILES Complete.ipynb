# %% [markdown]
# <a href="https://colab.research.google.com/github/PrinceKalra27/COMP593/blob/main/WEEK_4_ADVANCED_SQL_AND_FILES%20Complete.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 4 - Advanced SQL / Writing Files
#
# In this week's lab, we are going to expand our Really Simple Social Network by adding another table that will record connections between people! Because after all, what good is a social network if you can't ... be social?
#
# Afterwards, we will be in a good position to run a report on the data, and then we can sell it to marketers for a massive profit! Isn't it great how few people read the terms of service? `/s`

# %% [markdown]
# ## Importing our database
# Since we are using a new colab notebook, we will need to reimport our database. Check your D2L Submission if you didn't keep a copy, you should be able to redownload it there. Run the below code block and the file upload picker will appear, after uploading your Database file, check that it appears in the `Files` tab of colab.
#
# Remember that you may need to update the listings before it will appear.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-614f0cba-8628-43f9-a1cb-7955d82d2d10" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-614f0cba-8628-43f9-a1cb-7955d82d2d10">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Lab3Database.db to Lab3Database.db

# %% [markdown]
# ## Creating our relationship table
#
# In the code block below, we will be creating a new table in our database for `relationships` with the following parameters:
#
#
# 1.   A primary key column called `id` with the `INTEGER` datatype that is `NOT NULL`
# 2.   A foreign key column called `user_id` that links to the `id` column of the `people` table with the `INTEGER` datatype that is `NOT NULL`
# 3.   Another foreign key column called `friend_id` that also links to the `id` column of the `people` table with the `INTEGER` datatype that is `NOT NULL`
# 4.   A `date_created` table with the `DATE` datatype that is `NOT NULL`
#
# The Below codeblock will get you started:

# %%
import sqlite3

#Retreive the Connection object, rename the file to match your uploaded DB if necessary.
myLab3connect = sqlite3.connect('Lab3Database.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myLab3connect.cursor()

#The Primary Key column has been provided for you,
#Replace '#!...' with the remaining column names, datatypes, and foreign key declarations.
#Use the Lecture notes and the previous lab if you are unsure.
createRelationshipsTable = """CREATE TABLE IF NOT EXISTS relationships (
                          id integer PRIMARY KEY NOT NULL,
                          user_id integer NOT NULL,
                          friend_id integer NOT NULL,
                          FOREIGN KEY (user_id) REFERENCES people (id),
                          FOREIGN KEY (friend_id) REFERENCES people (id)
                        );"""

#Once again, we will execute the query, persist the changes, and close our connection.
myCursor.execute(createRelationshipsTable)
myLab3connect.commit()
myLab3connect.close()

# %%
#Retrieving
myLab3connect = sqlite3.connect('Lab3Database.db')
myCursor = myLab3connect.cursor()

myCursor.execute("Select group_concat(name, ', ') FROM pragma_table_info('relationships')")
print(myCursor.fetchone())

myLab3connect.close
# Out:
# ('id, user_id, friend_id',)
# <function Connection.close>

# %% [markdown]
# ## Populating Relationship Data
#
# We're not going to be picky about who knows who - so for the purposes of this lab, we're going to use our own version of an AI matchmaker, the `randrange()` method.
#
# Complete the below codeblock, inserting 1000 new rows into the relationships table.
# Use a random number between `1 - 1000` for the `user_id` and `friend_id` columns. This will link up to the `id` column of the `people` table and effectivly simulate a random network of relationships.
#
# The below code block is purposely sparse, as you should be able to use the patterns you've identified in the previous lab to complete this task.

# %%
import sqlite3
from datetime import datetime #For generating dates and times
from random import randrange #For generating random numbers within a range

#Retreive the Connection object, rename the file to match your uploaded DB if necessary.
myLab3connect = sqlite3.connect('Lab3Database.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myLab3connect.cursor()

#Complete the below query
relationQuery =  """INSERT INTO relationships (user_id, friend_id)
            Values (?, ?);"""

for _ in range(1000):
  #Populate the arguments that will be used in the query
  user_id = randrange(1, 1000)

  friend_id = user_id
  while friend_id == user_id:
    friend_id = randrange(1, 1000)

  args = (user_id, friend_id)
  #Execute the query
  myCursor.execute(relationQuery, args)

#Commit your changes and close the connection.
myLab3connect.commit()
myLab3connect.close()

# %%
import sqlite3
import pprint

#Retreiving the Connection object
mylab3connect = sqlite3.connect('Lab3Database.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = mylab3connect.cursor()

#Statement to get result
Code_statmnt = """SELECT * FROM relationships LIMIT 20"""




myCursor.execute(Code_statmnt)
rslts = myCursor.fetchall()
pprint.pprint(rslts)
# Out:
# [(1, 774, 926),
#  (2, 710, 498),
#  (3, 796, 578),
#  (4, 239, 189),
#  (5, 739, 646),
#  (6, 512, 627),
#  (7, 184, 250),
#  (8, 333, 204),
#  (9, 917, 286),
#  (10, 435, 940),
#  (11, 597, 622),
#  (12, 168, 695),
#  (13, 864, 232),
#  (14, 312, 186),
#  (15, 145, 686),
#  (16, 245, 823),
#  (17, 784, 420),
#  (18, 167, 847),
#  (19, 86, 109),
#  (20, 58, 837)]

# %% [markdown]
# ## Building our Report
#
# Now that our AI Matchmaker has generated our network of relationships, a marketing firm is offering us boatloads of cash for information about the amount of friends the users of our social network have.
#
# The request is to return the name of each user, and the total number of relationships they have made.
#
# If this was explained in awkward pseudo code, it might go something like this:
# ```
# SELECT all relationships
# JOIN them to the people they belong to
# GROUP the results by the person's ID
# return the person's name and COUNT of their relationships
# ```
#
# After you have collected the data, you will need to write it to a `.txt` file.
#
# **Your submission will include the report `.txt` file, the copy of your updated `social_network.db` file, and a link to the colab notebook.**
#
# Look at the aggregate functions from Week 3 and the Join examples from Week 4. There are a few different ways that you can structure a query to reach the correct answer.
#
# **At a minimum, you will need to use a `LEFT JOIN` statement, a `GROUP BY` statement, and a `COUNT()` aggregate function.**
#
# The below code block will get you started:

# %%
import sqlite3
import pprint

#Retreive the Connection object, rename the file to match your uploaded DB if necessary.
myLab3connect = sqlite3.connect('Lab3Database.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myLab3connect.cursor()

#Uncomment the below line after you have determined what the correct mode will be for your file pointer.
#fp = open('report.txt', mode='')

#Complete the below query
query =  """SELECT people.name, COUNT(*)FROM relationships JOIN people ON relationships.user_id = people.id
            GROUP BY relationships.user_id
         """

myCursor.execute(query)
results = myCursor.fetchall()
pprint.pprint(results)
myLab3connect.close()

fp = open('Lab4Textfile.txt' , mode='w')
  #You will want to write the results to the file pointer here.

for result in results:
  
  Lines = result[0] + " has " + str(result[1]) + " relationships.\n"
  fp.write(Lines)
  print(Lines)

fp.close() 
  #Use the newline character \n to create a line break in each write() statement.
  #Use print() statements as sanity checks if you are unsure of the integrity of your data.

#Don't forget to close the file pointer after you have finished!
# Out:
# [('Natalie Ball', 1),
#  ('Jennifer Ortega', 1),
#  ('Matthew Evans', 6),
#  ('Jeff Smith', 1),
#  ('Jamie Scott', 1),
#  ('Tyrone Chang', 4),
#  ('Jaime Hammond', 2),
#  ('Christian Cummings', 1),
#  ('Jennifer Johnson', 3),
#  ('Linda Smith', 1),
#  ('Sherry Kim', 1),
#  ('Amanda Estes', 1),
#  ('Kenneth Williams', 1),
#  ('Victor Owens', 2),
#  ('Gary Graham', 1),
#  ('Richard Hart', 1),
#  ('Tracy Smith', 2),
#  ('Kenneth Haynes', 2),
#  ('Jonathan Haas', 1),
#  ('Joseph Shelton', 1),
#  ('Richard Diaz', 2),
#  ('Emma Garrett', 2),
#  ('Leah Johnson', 2),
#  ('Chris Rogers', 1),
#  ('James Brown', 1),
#  ('Timothy Mccarthy', 1),
#  ('Matthew Jones', 1),
#  ('Susan Bowers', 1),
#  ('Jason Hess', 2),
#  ('Margaret Morales', 1),
#  ('Sarah Lawson', 1),
#  ('Bethany Young', 2),
#  ('Sarah Cantu', 3),
#  ('Robert Peterson', 1),
#  ('Rachel Murphy', 1),
#  ('Norma Smith', 1),
#  ('Rhonda Phillips', 1),
#  ('Patricia Campbell', 2),
#  ('Stephen Perkins', 1),
#  ('Amber Harris', 1),
#  ('Edward Wyatt', 2),
#  ('Mark Barajas', 1),
#  ('Yvette Perez', 2),
#  ('Chris Clarke', 1),
#  ('Alejandro Davis', 3),
#  ('Kimberly Flores', 1),
#  ('Brian Miller', 1),
#  ('Brianna Salinas', 1),
#  ('Amanda Cabrera', 1),
#  ('Chad Huynh', 1),
#  ('Denise Howard', 1),
#  ('Michael Bishop Jr.', 3),
#  ('Brandon Becker', 2),
#  ('Joseph Cardenas', 2),
#  ('Rachel Bridges', 3),
#  ('Nichole Hayes', 2),
#  ('Marc Lee', 3),
#  ('Michael Matthews', 1),
#  ('Bryan Jackson', 1),
#  ('Michael Garner', 1),
#  ('Jennifer Miller', 1),
#  ('Craig Gutierrez', 1),
#  ('Mary Mitchell', 3),
#  ('Heather Daugherty', 1),
#  ('Amy Blair', 2),
#  ('Denise Skinner', 1),
#  ('Jeffrey Maynard', 2),
#  ('Shane Terry MD', 1),
#  ('Jonathan Massey', 1),
#  ('Kevin Mclean', 2),
#  ('Edward Henson', 1),
#  ('Nathaniel Carter', 2),
#  ('Vincent Montgomery', 2),
#  ('Katelyn Gray', 1),
#  ('Antonio Hebert', 1),
#  ('Jeremiah Jones', 1),
#  ('Dana Gordon', 1),
#  ('James Stone', 1),
#  ('Amber Smith', 1),
#  ('Garrett Figueroa', 1),
#  ('Claudia Lewis', 1),
#  ('Dr. Lauren Palmer', 2),
#  ('Rebekah Haley', 3),
#  ('William Bryant', 2),
#  ('Terry Cain', 1),
#  ('Craig Davis', 1),
#  ('Brenda Gill', 3),
#  ('Donna Allen', 1),
#  ('Jennifer Wilson', 3),
#  ('Robert Wilson', 3),
#  ('Tina Barrera MD', 1),
#  ('Trevor Jones', 1),
#  ('Lee Moyer', 2),
#  ('Tyler Jensen', 1),
#  ('Elizabeth Wilkinson', 1),
#  ('Paul Thompson', 1),
#  ('Stacy Villegas', 3),
#  ('Christina Bowen', 3),
#  ('George Steele', 1),
#  ('Matthew White', 2),
#  ('Henry Hudson', 2),
#  ('Christina Roberts', 1),
#  ('Lindsey Jones', 1),
#  ('Jeffrey Martinez', 1),
#  ('Patricia Daniels', 1),
#  ('Adam Vaughn', 1),
#  ('Raymond Charles', 3),
#  ('Jennifer Smith', 2),
#  ('Martin Deleon', 1),
#  ('Michelle Wallace', 3),
#  ('David Williams', 2),
#  ('Sabrina Evans', 1),
#  ('Stacy Barber', 1),
#  ('Tamara Carroll', 1),
#  ('Gabriel Brock', 2),
#  ('Brianna Velazquez', 2),
#  ('John Nelson', 1),
#  ('Linda Smith', 1),
#  ('Kristen Gibbs', 1),
#  ('Erika Wu', 2),
#  ('Megan Hester', 1),
#  ('Jason Edwards', 2),
#  ('Joseph Hernandez', 1),
#  ('Michael Petty', 2),
#  ('Kyle Singh', 2),
#  ('Lisa Stewart', 1),
#  ('David Sanchez', 1),
#  ('Michael Friedman', 1),
#  ('Brett Hansen', 2),
#  ('Cynthia Arnold', 3),
#  ('Thomas Lee', 1),
#  ('Karen Howard', 2),
#  ('Jennifer Lowe', 2),
#  ('Mark Rose', 2),
#  ('Courtney Johns', 1),
#  ('Anthony Hayes', 1),
#  ('Patricia Johnson', 1),
#  ('Timothy Flores', 1),
#  ('Makayla Smith', 1),
#  ('Jacob Johnson', 3),
#  ('Antonio Sosa', 1),
#  ('Stephanie Beltran', 2),
#  ('Jonathan Williamson', 1),
#  ('Victoria Lee', 1),
#  ('Amanda Bartlett', 1),
#  ('Timothy Acosta', 1),
#  ('Hector Perez', 1),
#  ('Amanda Cox', 1),
#  ('Ariana Cox', 1),
#  ('Jessica Diaz', 1),
#  ('Marcus Stanley', 1),
#  ('Alexandra Williams', 1),
#  ('Kevin Lopez', 1),
#  ('Jason Wheeler', 3),
#  ('Jennifer Francis', 1),
#  ('David Hall', 1),
#  ('Ralph Fowler', 1),
#  ('Jessica Pierce', 1),
#  ('Megan Villanueva', 2),
#  ('Theodore Lee', 1),
#  ('Erik Ortiz', 2),
#  ('Vickie Lee', 2),
#  ('Stephanie Johnson', 3),
#  ('Lisa Kent', 1),
#  ('Bailey Jones', 1),
#  ('Stacy Lee', 2),
#  ('Mr. Tony Vega PhD', 1),
#  ('Ian Rivera', 1),
#  ('Leslie Pierce', 1),
#  ('Timothy Turner', 2),
#  ('Lauren Kelley', 1),
#  ('Jeffrey Murray', 3),
#  ('Kathy Phillips', 1),
#  ('Alexandria Berry', 1),
#  ('Amanda Burns', 2),
#  ('John Ellis', 4),
#  ('Jennifer Coleman', 1),
#  ('James Vasquez', 1),
#  ('Stacey Kirby', 1),
#  ('Crystal Leon', 2),
#  ('Jessica Williams', 1),
#  ('Michelle Johnson', 1),
#  ('William Tate Jr.', 1),
#  ('Brianna Rhodes', 2),
#  ('David Mejia', 1),
#  ('Taylor Sherman', 2),
#  ('David Owens', 1),
#  ('Lindsey Allison', 1),
#  ('Julie Evans', 1),
#  ('Roberto Ortega', 1),
#  ('Zachary Diaz', 2),
#  ('Krista Davis', 2),
#  ('Claudia Moody', 1),
#  ('Samantha Charles', 1),
#  ('Jessica Martinez PhD', 3),
#  ('Susan Molina', 2),
#  ('Heather Henderson', 3),
#  ('Roger Dixon', 2),
#  ('Allison Torres', 3),
#  ('Kendra Miller', 3),
#  ('Andrea Anderson', 1),
#  ('Adam Walker', 1),
#  ('Michael Navarro', 2),
#  ('Christy White', 2),
#  ('Alexander Simpson', 2),
#  ('Kristen Thomas', 1),
#  ('Kristi Haynes', 2),
#  ('Scott Crawford', 1),
#  ('Annette Morgan', 1),
#  ('Veronica Horton', 1),
#  ('Joseph Raymond', 5),
#  ('Diana Jackson', 3),
#  ('Jeremy Williamson', 2),
#  ('Mary Drake', 1),
#  ('Barbara Lutz', 2),
#  ('Judith Ryan', 1),
#  ('Mary Rivera', 1),
#  ('Rita Mitchell', 1),
#  ('Alexis Carter', 2),
#  ('Brad Wilson', 1),
#  ('Richard Meyers', 1),
#  ('Courtney Rodriguez', 1),
#  ('Benjamin Leonard', 1),
#  ('Aimee Miller', 1),
#  ('Allison Grant', 1),
#  ('James Benson', 1),
#  ('Travis Tucker', 1),
#  ('Michael Mcclure', 1),
#  ('Elaine Lawrence', 2),
#  ('Annette Carter', 2),
#  ('Sarah Medina', 1),
#  ('Peter Sherman', 1),
#  ('Victor Morris', 3),
#  ('Christopher Foley', 1),
#  ('Patricia Barr', 2),
#  ('Elizabeth Lutz', 1),
#  ('Jeremy Lang', 1),
#  ('Cory Johnston', 2),
#  ('Sierra Wallace', 1),
#  ('Jamie Jones', 1),
#  ('Terry Thomas', 2),
#  ('Samuel Cooke', 1),
#  ('Monica Ortiz', 3),
#  ('Mrs. Miranda Freeman MD', 1),
#  ('Christopher Crane', 1),
#  ('Jason Sanders', 1),
#  ('Diane Walter', 1),
#  ('Matthew Mcmillan', 1),
#  ('Michelle Hernandez MD', 3),
#  ('David Wilson', 1),
#  ('Joseph Moore DDS', 1),
#  ('Johnny Wade', 1),
#  ('Richard Baker', 1),
#  ('Rachel Barnett', 1),
#  ('Lynn Rocha', 2),
#  ('Gregory Owens', 1),
#  ('Adam Hicks', 1),
#  ('Scott Murphy', 1),
#  ('Elizabeth Berry', 3),
#  ('Susan Fox', 1),
#  ('Spencer Ellis', 1),
#  ('Michael Orr', 2),
#  ('Ryan Reed', 2),
#  ('Meghan Joseph', 2),
#  ('Stacy Trevino', 2),
#  ('April Ross', 2),
#  ('Anthony Chan', 1),
#  ('Patrick Hale', 2),
#  ('Kimberly Summers', 3),
#  ('Tina Mccullough', 1),
#  ('Michael Vega', 1),
#  ('Jeffrey Hughes', 2),
#  ('Andrew Sullivan', 1),
#  ('Joshua Wright', 1),
#  ('Michael Hernandez', 1),
#  ('Patricia Guerra', 1),
#  ('Linda Morales', 2),
#  ('Alyssa Scott', 1),
#  ('Kristen Clark', 4),
#  ('William Parker', 1),
#  ('Jacob Chung', 1),
#  ('Daniel Bond', 1),
#  ('Andrew Hobbs', 1),
#  ('Brent Patterson', 2),
#  ('Michelle Holt', 1),
#  ('Michael Porter', 2),
#  ('Cynthia Harris', 2),
#  ('Timothy Beck', 1),
#  ('Maria Graham', 1),
#  ('Timothy Rowland', 1),
#  ('Billy Campbell', 1),
#  ('Carrie Cooper', 2),
#  ('Renee Miller', 1),
#  ('Shannon Miller', 1),
#  ('Joel Hill', 1),
#  ('Brian Porter', 4),
#  ('Tiffany Simpson', 1),
#  ('Jeffrey Young', 1),
#  ('Kimberly Sweeney', 2),
#  ('Michael Rowe', 1),
#  ('Michael Peters', 1),
#  ('Bryan Simpson', 2),
#  ('Olivia Morgan', 3),
#  ('Tanya Jimenez', 1),
#  ('Andre Brown', 2),
#  ('Lisa Leonard', 2),
#  ('Michael Roberson', 2),
#  ('Elizabeth Conner', 1),
#  ('Christopher Floyd', 3),
#  ('Ronald Sullivan', 2),
#  ('Veronica Hernandez', 2),
#  ('Kylie Carlson', 2),
#  ('Christopher Wilkinson', 1),
#  ('Mary Thornton MD', 1),
#  ('Jason Duffy', 1),
#  ('Heather Trevino', 2),
#  ('Christopher Stephens', 2),
#  ('Jennifer Salas', 1),
#  ('Jonathan Wood', 3),
#  ('Dustin Decker', 1),
#  ('Antonio Brown', 1),
#  ('Matthew Yoder', 1),
#  ('Shannon Miller', 3),
#  ('Victoria Lewis', 1),
#  ('Shane Houston', 1),
#  ('Sara Weaver', 1),
#  ('Megan Ray', 1),
#  ('Justin Cooley', 2),
#  ('Lisa King', 4),
#  ('Charles Peterson', 3),
#  ('Christine Hall', 1),
#  ('Andrew Rodriguez', 1),
#  ('Thomas Lopez', 1),
#  ('Margaret Parrish', 2),
#  ('Jennifer Baker', 1),
#  ('Jamie Ramirez', 1),
#  ('Gary Cook', 3),
#  ('Nicholas Martin', 1),
#  ('Julie White', 2),
#  ('Allison Powers', 1),
#  ('Kenneth Baker', 2),
#  ('Chris Wallace', 1),
#  ('Angel Williamson', 2),
#  ('Eric Patel', 4),
#  ('Angel Robinson', 1),
#  ('Ann Johnson', 1),
#  ('Cole Palmer', 2),
#  ('Scott George', 3),
#  ('Stephen Bryant', 2),
#  ('Jonathon Howell', 1),
#  ('James Watson', 3),
#  ('Jose Watkins', 1),
#  ('Christian Simmons', 2),
#  ('Mike Sullivan', 2),
#  ('Trevor Harrell', 2),
#  ('John Walter', 1),
#  ('Heather Smith', 3),
#  ('Maria Chavez', 3),
#  ('Leah Williams', 1),
#  ('Joyce Hall', 1),
#  ('Rebecca Wilson', 2),
#  ('Joshua Taylor', 1),
#  ('George Smith', 2),
#  ('Amy Russo', 1),
#  ('Linda Myers', 1),
#  ('Kayla Johnson', 3),
#  ('Phillip Carter', 1),
#  ('Jennifer Huang', 1),
#  ('Paige Harris', 2),
#  ('Brent Morgan', 1),
#  ('Andrew Phelps', 1),
#  ('Christian Peters', 1),
#  ('Bradley Brady', 1),
#  ('Ruth Williamson', 1),
#  ('Ashley Evans', 2),
#  ('Margaret Reed', 1),
#  ('Hannah Jackson', 1),
#  ('Jennifer Warren', 4),
#  ('Jessica Robinson', 1),
#  ('Wesley Mcdonald', 2),
#  ('Darryl Le', 4),
#  ('Richard Young', 2),
#  ('Traci Brown', 2),
#  ('Heidi Martin', 1),
#  ('Nicholas Rojas', 5),
#  ('Cynthia Harrison', 1),
#  ('Abigail King', 1),
#  ('Timothy Hess', 1),
#  ('Susan Ware', 2),
#  ('David Roach', 1),
#  ('Lisa Oliver', 1),
#  ('Michael Turner', 3),
#  ('Joseph Castillo', 1),
#  ('Jennifer Griffin', 2),
#  ('Ricky Norris', 2),
#  ('Gordon Graham', 1),
#  ('Michelle Donovan', 2),
#  ('Todd Roberts', 1),
#  ('Peter Washington', 1),
#  ('Mario Adams', 3),
#  ('Stephanie Ortiz', 3),
#  ('Mr. Joshua Bell', 2),
#  ('Stephen Kelley', 2),
#  ('Alexander Garcia', 4),
#  ('Lauren Santiago', 2),
#  ('Katherine Hoffman', 1),
#  ('Laura Young', 1),
#  ('Oscar Matthews', 1),
#  ('Charles Escobar', 1),
#  ('Jonathan Simpson', 2),
#  ('Christopher Hill', 1),
#  ('Chris Brown', 1),
#  ('Jessica Ashley', 3),
#  ('Melinda Romero', 2),
#  ('Ryan Sharp', 2),
#  ('Kelly Miller', 1),
#  ('Rebecca Vargas', 1),
#  ('Brandon Thompson', 1),
#  ('Melissa Faulkner', 2),
#  ('Joshua Johnson', 3),
#  ('Kimberly Hall', 2),
#  ('Isaiah Ellis', 1),
#  ('Melissa Robinson', 2),
#  ('Sylvia Young DDS', 3),
#  ('Amanda Wheeler', 1),
#  ('Angela Kim', 1),
#  ('David Briggs', 1),
#  ('Daniel King', 1),
#  ('Debra Wilson', 1),
#  ('Tracy Caldwell', 1),
#  ('Wendy Brewer', 1),
#  ('Jesse Martin', 4),
#  ('Michael Smith', 2),
#  ('Kelly Thompson', 1),
#  ('Kevin Garcia', 4),
#  ('Dr. Billy Washington', 3),
#  ('Jessica Craig', 1),
#  ('Sheila Goodman', 2),
#  ('Samantha Alvarez', 3),
#  ('Janet Robinson', 1),
#  ('Mr. Jerry Martinez', 1),
#  ('Daniel Matthews', 2),
#  ('Hannah Lynch', 1),
#  ('Shane Gill', 1),
#  ('Michael Martin', 1),
#  ('Samuel Pratt', 2),
#  ('Kathleen Petersen', 1),
#  ('Kenneth Evans', 1),
#  ('Lisa Sandoval', 1),
#  ('Mr. Thomas Warren', 1),
#  ('Ms. Rhonda Gray', 1),
#  ('Dawn Delgado', 1),
#  ('Dr. Matthew Campbell', 2),
#  ('Lynn Jones', 1),
#  ('Emma Perry', 2),
#  ('Melissa Martin', 1),
#  ('Sarah Thomas', 4),
#  ('Lynn Koch', 1),
#  ('Robert George', 2),
#  ('James Case', 4),
#  ('Carolyn Ballard', 1),
#  ('Diana Silva', 1),
#  ('Tanner West', 3),
#  ('Ashley Rivera', 2),
#  ('Robert Diaz', 2),
#  ('Christine Benson', 2),
#  ('Edwin Ochoa', 1),
#  ('Kevin Scott', 2),
#  ('Samantha Padilla', 3),
#  ('Rebecca Gilbert', 2),
#  ('Teresa Rosales', 1),
#  ('Lorraine Snyder', 4),
#  ('Jacqueline Morris', 1),
#  ('Jason Scott', 1),
#  ('Christopher Young', 2),
#  ('Michelle Kennedy', 2),
#  ('Maria Shepard', 3),
#  ('Candace Lewis', 1),
#  ('John Murillo', 1),
#  ('Seth Obrien', 1),
#  ('Cheryl Davis', 1),
#  ('Kristina Gutierrez', 2),
#  ('Andrew James', 1),
#  ('Michael Andrews', 1),
#  ('Michael Rowe', 2),
#  ('Johnny Daniel', 3),
#  ('Julie Briggs', 1),
#  ('Mark White', 3),
#  ('Richard Vasquez', 2),
#  ('William Guerrero', 2),
#  ('Marvin Johnson', 1),
#  ('Brandon Guzman', 3),
#  ('Heather Taylor', 2),
#  ('Rachel Jackson', 4),
#  ('Dawn Douglas', 2),
#  ('Randall Park', 1),
#  ('Bryan Hughes', 1),
#  ('Michael Martin', 1),
#  ('Amanda Gomez', 1),
#  ('Brittney Hawkins', 3),
#  ('Rebecca Jimenez', 1),
#  ('Ryan Aguilar', 1),
#  ('Ashley Dennis', 1),
#  ('Bryan Williams', 1),
#  ('Terry Smith', 5),
#  ('Donna Jones', 1),
#  ('Sarah Morgan', 2),
#  ('Amanda Meadows', 1),
#  ('Michelle Larsen', 1),
#  ('Benjamin Johnston', 1),
#  ('Katherine Levy', 3),
#  ('Natalie Williams', 1),
#  ('Tracy White', 1),
#  ('Lisa Velez', 3),
#  ('Ralph Davis', 1),
#  ('Samuel Vaughan', 1),
#  ('Valerie Adams', 1),
#  ('Benjamin Simmons', 2),
#  ('Matthew Martin PhD', 1),
#  ('James Sanchez', 2),
#  ('Susan Leonard', 2),
#  ('Erica Jones', 1),
#  ('Richard Wagner', 1),
#  ('Amanda Campbell', 2),
#  ('Matthew Bell', 1),
#  ('Adam Stephens', 1),
#  ('Miss Maria Gibson', 1),
#  ('Daniel Riley MD', 1),
#  ('Peter Adams', 1),
#  ('Dr. Bridget Holloway DDS', 1),
#  ('Devin Williams', 4),
#  ('Margaret Scott', 1),
#  ('Aaron Stokes', 2),
#  ('Ryan Patterson', 3),
#  ('Rebecca Horn', 2),
#  ('Samantha King', 1),
#  ('Emily Gonzalez', 1),
#  ('Maria Small', 2),
#  ('Eileen Smith', 4),
#  ('Angelica Wilson', 2),
#  ('Jason Marsh', 1),
#  ('Marc Molina', 1),
#  ('Linda Allen', 1),
#  ('Jasmine Miller', 2),
#  ('Travis Shields', 2),
#  ('Cheryl Rich', 2),
#  ('Vanessa Watson', 1),
#  ('Sarah Williams', 1),
#  ('Dean Johnson', 2),
#  ('Steven Klein', 2),
#  ('Kyle Brennan', 1),
#  ('Kaitlin Mcguire', 1),
#  ('Edward Barnes', 1),
#  ('Allison Thompson', 2),
#  ('Patricia Mathews', 1),
#  ('Edward Thompson', 2),
#  ('William Taylor', 1),
#  ('Daniel Joyce', 2),
#  ('Jonathan Larson DDS', 2),
#  ('Mark Perez', 2),
#  ('Amy Jordan', 3),
#  ('Bobby Bright', 3),
#  ('Allison King', 1),
#  ('Kaitlyn Hanson', 3),
#  ('James Conner', 2),
#  ('Joanna Anderson', 1),
#  ('Justin Ward', 2),
#  ('Holly Taylor', 1),
#  ('Jeffrey Riley', 1),
#  ('Haley Porter', 2),
#  ('Sally Williams', 2),
#  ('Emily Parker', 1),
#  ('William Murphy', 2),
#  ('Jerome Monroe', 1),
#  ('Marissa Lester', 1),
#  ('Andrea Guzman PhD', 3),
#  ('Linda Harrison', 3),
#  ('William Barrera MD', 2),
#  ('Teresa Collins', 1),
#  ('Mr. Eric Johnson', 2),
#  ('Alexa Brady', 1),
#  ('Jessica Wallace', 1),
#  ('Anna Cochran', 2),
#  ('Yolanda King', 1),
#  ('Julie Peterson', 1),
#  ('Benjamin Jones', 1),
#  ('Steven Blackburn', 1),
#  ('Mary Espinoza', 2),
#  ('Jason Salinas', 1),
#  ('Stephanie Salazar', 2),
#  ('Sydney House', 2),
#  ('Jessica Evans', 1),
#  ('Bill Moreno', 4),
#  ('Johnathan Payne', 2),
#  ('Elizabeth Jones', 2),
#  ('Linda Cook', 2),
#  ('Amanda Simmons', 2),
#  ('Katelyn Mooney', 2),
#  ('Kristen Lee', 2),
#  ('Christopher Mahoney', 3),
#  ('Dylan Sweeney', 1),
#  ('Brooke Martin', 3),
#  ('Amy Campbell', 1),
#  ('Matthew Butler', 1),
#  ('Joshua Mendez', 1),
#  ('Mrs. Ashley Bartlett DVM', 1),
#  ('Michelle Wright', 2),
#  ('William Kelly', 2),
#  ('Melissa Martin', 1),
#  ('Mark Colon', 1),
#  ('Andrew Allen', 1),
#  ('Tanya Hensley', 3),
#  ('Kevin Davis', 1),
#  ('Mrs. Lisa Griffith MD', 2),
#  ('Jesse Wells', 1),
#  ('Jacob Sutton', 3),
#  ('Jacqueline Martin', 1),
#  ('Kyle Figueroa', 1)]
# Natalie Ball has 1 relationships.
#
# Jennifer Ortega has 1 relationships.
#
# Matthew Evans has 6 relationships.
#
# Jeff Smith has 1 relationships.
#
# Jamie Scott has 1 relationships.
#
# Tyrone Chang has 4 relationships.
#
# Jaime Hammond has 2 relationships.
#
# Christian Cummings has 1 relationships.
#
# Jennifer Johnson has 3 relationships.
#
# Linda Smith has 1 relationships.
#
# Sherry Kim has 1 relationships.
#
# Amanda Estes has 1 relationships.
#
# Kenneth Williams has 1 relationships.
#
# Victor Owens has 2 relationships.
#
# Gary Graham has 1 relationships.
#
# Richard Hart has 1 relationships.
#
# Tracy Smith has 2 relationships.
#
# Kenneth Haynes has 2 relationships.
#
# Jonathan Haas has 1 relationships.
#
# Joseph Shelton has 1 relationships.
#
# Richard Diaz has 2 relationships.
#
# Emma Garrett has 2 relationships.
#
# Leah Johnson has 2 relationships.
#
# Chris Rogers has 1 relationships.
#
# James Brown has 1 relationships.
#
# Timothy Mccarthy has 1 relationships.
#
# Matthew Jones has 1 relationships.
#
# Susan Bowers has 1 relationships.
#
# Jason Hess has 2 relationships.
#
# Margaret Morales has 1 relationships.
#
# Sarah Lawson has 1 relationships.
#
# Bethany Young has 2 relationships.
#
# Sarah Cantu has 3 relationships.
#
# Robert Peterson has 1 relationships.
#
# Rachel Murphy has 1 relationships.
#
# Norma Smith has 1 relationships.
#
# Rhonda Phillips has 1 relationships.
#
# Patricia Campbell has 2 relationships.
#
# Stephen Perkins has 1 relationships.
#
# Amber Harris has 1 relationships.
#
# Edward Wyatt has 2 relationships.
#
# Mark Barajas has 1 relationships.
#
# Yvette Perez has 2 relationships.
#
# Chris Clarke has 1 relationships.
#
# Alejandro Davis has 3 relationships.
#
# Kimberly Flores has 1 relationships.
#
# Brian Miller has 1 relationships.
#
# Brianna Salinas has 1 relationships.
#
# Amanda Cabrera has 1 relationships.
#
# Chad Huynh has 1 relationships.
#
# Denise Howard has 1 relationships.
#
# Michael Bishop Jr. has 3 relationships.
#
# Brandon Becker has 2 relationships.
#
# Joseph Cardenas has 2 relationships.
#
# Rachel Bridges has 3 relationships.
#
# Nichole Hayes has 2 relationships.
#
# Marc Lee has 3 relationships.
#
# Michael Matthews has 1 relationships.
#
# Bryan Jackson has 1 relationships.
#
# Michael Garner has 1 relationships.
#
# Jennifer Miller has 1 relationships.
#
# Craig Gutierrez has 1 relationships.
#
# Mary Mitchell has 3 relationships.
#
# Heather Daugherty has 1 relationships.
#
# Amy Blair has 2 relationships.
#
# Denise Skinner has 1 relationships.
#
# Jeffrey Maynard has 2 relationships.
#
# Shane Terry MD has 1 relationships.
#
# Jonathan Massey has 1 relationships.
#
# Kevin Mclean has 2 relationships.
#
# Edward Henson has 1 relationships.
#
# Nathaniel Carter has 2 relationships.
#
# Vincent Montgomery has 2 relationships.
#
# Katelyn Gray has 1 relationships.
#
# Antonio Hebert has 1 relationships.
#
# Jeremiah Jones has 1 relationships.
#
# Dana Gordon has 1 relationships.
#
# James Stone has 1 relationships.
#
# Amber Smith has 1 relationships.
#
# Garrett Figueroa has 1 relationships.
#
# Claudia Lewis has 1 relationships.
#
# Dr. Lauren Palmer has 2 relationships.
#
# Rebekah Haley has 3 relationships.
#
# William Bryant has 2 relationships.
#
# Terry Cain has 1 relationships.
#
# Craig Davis has 1 relationships.
#
# Brenda Gill has 3 relationships.
#
# Donna Allen has 1 relationships.
#
# Jennifer Wilson has 3 relationships.
#
# Robert Wilson has 3 relationships.
#
# Tina Barrera MD has 1 relationships.
#
# Trevor Jones has 1 relationships.
#
# Lee Moyer has 2 relationships.
#
# Tyler Jensen has 1 relationships.
#
# Elizabeth Wilkinson has 1 relationships.
#
# Paul Thompson has 1 relationships.
#
# Stacy Villegas has 3 relationships.
#
# Christina Bowen has 3 relationships.
#
# George Steele has 1 relationships.
#
# Matthew White has 2 relationships.
#
# Henry Hudson has 2 relationships.
#
# Christina Roberts has 1 relationships.
#
# Lindsey Jones has 1 relationships.
#
# Jeffrey Martinez has 1 relationships.
#
# Patricia Daniels has 1 relationships.
#
# Adam Vaughn has 1 relationships.
#
# Raymond Charles has 3 relationships.
#
# Jennifer Smith has 2 relationships.
#
# Martin Deleon has 1 relationships.
#
# Michelle Wallace has 3 relationships.
#
# David Williams has 2 relationships.
#
# Sabrina Evans has 1 relationships.
#
# Stacy Barber has 1 relationships.
#
# Tamara Carroll has 1 relationships.
#
# Gabriel Brock has 2 relationships.
#
# Brianna Velazquez has 2 relationships.
#
# John Nelson has 1 relationships.
#
# Linda Smith has 1 relationships.
#
# Kristen Gibbs has 1 relationships.
#
# Erika Wu has 2 relationships.
#
# Megan Hester has 1 relationships.
#
# Jason Edwards has 2 relationships.
#
# Joseph Hernandez has 1 relationships.
#
# Michael Petty has 2 relationships.
#
# Kyle Singh has 2 relationships.
#
# Lisa Stewart has 1 relationships.
#
# David Sanchez has 1 relationships.
#
# Michael Friedman has 1 relationships.
#
# Brett Hansen has 2 relationships.
#
# Cynthia Arnold has 3 relationships.
#
# Thomas Lee has 1 relationships.
#
# Karen Howard has 2 relationships.
#
# Jennifer Lowe has 2 relationships.
#
# Mark Rose has 2 relationships.
#
# Courtney Johns has 1 relationships.
#
# Anthony Hayes has 1 relationships.
#
# Patricia Johnson has 1 relationships.
#
# Timothy Flores has 1 relationships.
#
# Makayla Smith has 1 relationships.
#
# Jacob Johnson has 3 relationships.
#
# Antonio Sosa has 1 relationships.
#
# Stephanie Beltran has 2 relationships.
#
# Jonathan Williamson has 1 relationships.
#
# Victoria Lee has 1 relationships.
#
# Amanda Bartlett has 1 relationships.
#
# Timothy Acosta has 1 relationships.
#
# Hector Perez has 1 relationships.
#
# Amanda Cox has 1 relationships.
#
# Ariana Cox has 1 relationships.
#
# Jessica Diaz has 1 relationships.
#
# Marcus Stanley has 1 relationships.
#
# Alexandra Williams has 1 relationships.
#
# Kevin Lopez has 1 relationships.
#
# Jason Wheeler has 3 relationships.
#
# Jennifer Francis has 1 relationships.
#
# David Hall has 1 relationships.
#
# Ralph Fowler has 1 relationships.
#
# Jessica Pierce has 1 relationships.
#
# Megan Villanueva has 2 relationships.
#
# Theodore Lee has 1 relationships.
#
# Erik Ortiz has 2 relationships.
#
# Vickie Lee has 2 relationships.
#
# Stephanie Johnson has 3 relationships.
#
# Lisa Kent has 1 relationships.
#
# Bailey Jones has 1 relationships.
#
# Stacy Lee has 2 relationships.
#
# Mr. Tony Vega PhD has 1 relationships.
#
# Ian Rivera has 1 relationships.
#
# Leslie Pierce has 1 relationships.
#
# Timothy Turner has 2 relationships.
#
# Lauren Kelley has 1 relationships.
#
# Jeffrey Murray has 3 relationships.
#
# Kathy Phillips has 1 relationships.
#
# Alexandria Berry has 1 relationships.
#
# Amanda Burns has 2 relationships.
#
# John Ellis has 4 relationships.
#
# Jennifer Coleman has 1 relationships.
#
# James Vasquez has 1 relationships.
#
# Stacey Kirby has 1 relationships.
#
# Crystal Leon has 2 relationships.
#
# Jessica Williams has 1 relationships.
#
# Michelle Johnson has 1 relationships.
#
# William Tate Jr. has 1 relationships.
#
# Brianna Rhodes has 2 relationships.
#
# David Mejia has 1 relationships.
#
# Taylor Sherman has 2 relationships.
#
# David Owens has 1 relationships.
#
# Lindsey Allison has 1 relationships.
#
# Julie Evans has 1 relationships.
#
# Roberto Ortega has 1 relationships.
#
# Zachary Diaz has 2 relationships.
#
# Krista Davis has 2 relationships.
#
# Claudia Moody has 1 relationships.
#
# Samantha Charles has 1 relationships.
#
# Jessica Martinez PhD has 3 relationships.
#
# Susan Molina has 2 relationships.
#
# Heather Henderson has 3 relationships.
#
# Roger Dixon has 2 relationships.
#
# Allison Torres has 3 relationships.
#
# Kendra Miller has 3 relationships.
#
# Andrea Anderson has 1 relationships.
#
# Adam Walker has 1 relationships.
#
# Michael Navarro has 2 relationships.
#
# Christy White has 2 relationships.
#
# Alexander Simpson has 2 relationships.
#
# Kristen Thomas has 1 relationships.
#
# Kristi Haynes has 2 relationships.
#
# Scott Crawford has 1 relationships.
#
# Annette Morgan has 1 relationships.
#
# Veronica Horton has 1 relationships.
#
# Joseph Raymond has 5 relationships.
#
# Diana Jackson has 3 relationships.
#
# Jeremy Williamson has 2 relationships.
#
# Mary Drake has 1 relationships.
#
# Barbara Lutz has 2 relationships.
#
# Judith Ryan has 1 relationships.
#
# Mary Rivera has 1 relationships.
#
# Rita Mitchell has 1 relationships.
#
# Alexis Carter has 2 relationships.
#
# Brad Wilson has 1 relationships.
#
# Richard Meyers has 1 relationships.
#
# Courtney Rodriguez has 1 relationships.
#
# Benjamin Leonard has 1 relationships.
#
# Aimee Miller has 1 relationships.
#
# Allison Grant has 1 relationships.
#
# James Benson has 1 relationships.
#
# Travis Tucker has 1 relationships.
#
# Michael Mcclure has 1 relationships.
#
# Elaine Lawrence has 2 relationships.
#
# Annette Carter has 2 relationships.
#
# Sarah Medina has 1 relationships.
#
# Peter Sherman has 1 relationships.
#
# Victor Morris has 3 relationships.
#
# Christopher Foley has 1 relationships.
#
# Patricia Barr has 2 relationships.
#
# Elizabeth Lutz has 1 relationships.
#
# Jeremy Lang has 1 relationships.
#
# Cory Johnston has 2 relationships.
#
# Sierra Wallace has 1 relationships.
#
# Jamie Jones has 1 relationships.
#
# Terry Thomas has 2 relationships.
#
# Samuel Cooke has 1 relationships.
#
# Monica Ortiz has 3 relationships.
#
# Mrs. Miranda Freeman MD has 1 relationships.
#
# Christopher Crane has 1 relationships.
#
# Jason Sanders has 1 relationships.
#
# Diane Walter has 1 relationships.
#
# Matthew Mcmillan has 1 relationships.
#
# Michelle Hernandez MD has 3 relationships.
#
# David Wilson has 1 relationships.
#
# Joseph Moore DDS has 1 relationships.
#
# Johnny Wade has 1 relationships.
#
# Richard Baker has 1 relationships.
#
# Rachel Barnett has 1 relationships.
#
# Lynn Rocha has 2 relationships.
#
# Gregory Owens has 1 relationships.
#
# Adam Hicks has 1 relationships.
#
# Scott Murphy has 1 relationships.
#
# Elizabeth Berry has 3 relationships.
#
# Susan Fox has 1 relationships.
#
# Spencer Ellis has 1 relationships.
#
# Michael Orr has 2 relationships.
#
# Ryan Reed has 2 relationships.
#
# Meghan Joseph has 2 relationships.
#
# Stacy Trevino has 2 relationships.
#
# April Ross has 2 relationships.
#
# Anthony Chan has 1 relationships.
#
# Patrick Hale has 2 relationships.
#
# Kimberly Summers has 3 relationships.
#
# Tina Mccullough has 1 relationships.
#
# Michael Vega has 1 relationships.
#
# Jeffrey Hughes has 2 relationships.
#
# Andrew Sullivan has 1 relationships.
#
# Joshua Wright has 1 relationships.
#
# Michael Hernandez has 1 relationships.
#
# Patricia Guerra has 1 relationships.
#
# Linda Morales has 2 relationships.
#
# Alyssa Scott has 1 relationships.
#
# Kristen Clark has 4 relationships.
#
# William Parker has 1 relationships.
#
# Jacob Chung has 1 relationships.
#
# Daniel Bond has 1 relationships.
#
# Andrew Hobbs has 1 relationships.
#
# Brent Patterson has 2 relationships.
#
# Michelle Holt has 1 relationships.
#
# Michael Porter has 2 relationships.
#
# Cynthia Harris has 2 relationships.
#
# Timothy Beck has 1 relationships.
#
# Maria Graham has 1 relationships.
#
# Timothy Rowland has 1 relationships.
#
# Billy Campbell has 1 relationships.
#
# Carrie Cooper has 2 relationships.
#
# Renee Miller has 1 relationships.
#
# Shannon Miller has 1 relationships.
#
# Joel Hill has 1 relationships.
#
# Brian Porter has 4 relationships.
#
# Tiffany Simpson has 1 relationships.
#
# Jeffrey Young has 1 relationships.
#
# Kimberly Sweeney has 2 relationships.
#
# Michael Rowe has 1 relationships.
#
# Michael Peters has 1 relationships.
#
# Bryan Simpson has 2 relationships.
#
# Olivia Morgan has 3 relationships.
#
# Tanya Jimenez has 1 relationships.
#
# Andre Brown has 2 relationships.
#
# Lisa Leonard has 2 relationships.
#
# Michael Roberson has 2 relationships.
#
# Elizabeth Conner has 1 relationships.
#
# Christopher Floyd has 3 relationships.
#
# Ronald Sullivan has 2 relationships.
#
# Veronica Hernandez has 2 relationships.
#
# Kylie Carlson has 2 relationships.
#
# Christopher Wilkinson has 1 relationships.
#
# Mary Thornton MD has 1 relationships.
#
# Jason Duffy has 1 relationships.
#
# Heather Trevino has 2 relationships.
#
# Christopher Stephens has 2 relationships.
#
# Jennifer Salas has 1 relationships.
#
# Jonathan Wood has 3 relationships.
#
# Dustin Decker has 1 relationships.
#
# Antonio Brown has 1 relationships.
#
# Matthew Yoder has 1 relationships.
#
# Shannon Miller has 3 relationships.
#
# Victoria Lewis has 1 relationships.
#
# Shane Houston has 1 relationships.
#
# Sara Weaver has 1 relationships.
#
# Megan Ray has 1 relationships.
#
# Justin Cooley has 2 relationships.
#
# Lisa King has 4 relationships.
#
# Charles Peterson has 3 relationships.
#
# Christine Hall has 1 relationships.
#
# Andrew Rodriguez has 1 relationships.
#
# Thomas Lopez has 1 relationships.
#
# Margaret Parrish has 2 relationships.
#
# Jennifer Baker has 1 relationships.
#
# Jamie Ramirez has 1 relationships.
#
# Gary Cook has 3 relationships.
#
# Nicholas Martin has 1 relationships.
#
# Julie White has 2 relationships.
#
# Allison Powers has 1 relationships.
#
# Kenneth Baker has 2 relationships.
#
# Chris Wallace has 1 relationships.
#
# Angel Williamson has 2 relationships.
#
# Eric Patel has 4 relationships.
#
# Angel Robinson has 1 relationships.
#
# Ann Johnson has 1 relationships.
#
# Cole Palmer has 2 relationships.
#
# Scott George has 3 relationships.
#
# Stephen Bryant has 2 relationships.
#
# Jonathon Howell has 1 relationships.
#
# James Watson has 3 relationships.
#
# Jose Watkins has 1 relationships.
#
# Christian Simmons has 2 relationships.
#
# Mike Sullivan has 2 relationships.
#
# Trevor Harrell has 2 relationships.
#
# John Walter has 1 relationships.
#
# Heather Smith has 3 relationships.
#
# Maria Chavez has 3 relationships.
#
# Leah Williams has 1 relationships.
#
# Joyce Hall has 1 relationships.
#
# Rebecca Wilson has 2 relationships.
#
# Joshua Taylor has 1 relationships.
#
# George Smith has 2 relationships.
#
# Amy Russo has 1 relationships.
#
# Linda Myers has 1 relationships.
#
# Kayla Johnson has 3 relationships.
#
# Phillip Carter has 1 relationships.
#
# Jennifer Huang has 1 relationships.
#
# Paige Harris has 2 relationships.
#
# Brent Morgan has 1 relationships.
#
# Andrew Phelps has 1 relationships.
#
# Christian Peters has 1 relationships.
#
# Bradley Brady has 1 relationships.
#
# Ruth Williamson has 1 relationships.
#
# Ashley Evans has 2 relationships.
#
# Margaret Reed has 1 relationships.
#
# Hannah Jackson has 1 relationships.
#
# Jennifer Warren has 4 relationships.
#
# Jessica Robinson has 1 relationships.
#
# Wesley Mcdonald has 2 relationships.
#
# Darryl Le has 4 relationships.
#
# Richard Young has 2 relationships.
#
# Traci Brown has 2 relationships.
#
# Heidi Martin has 1 relationships.
#
# Nicholas Rojas has 5 relationships.
#
# Cynthia Harrison has 1 relationships.
#
# Abigail King has 1 relationships.
#
# Timothy Hess has 1 relationships.
#
# Susan Ware has 2 relationships.
#
# David Roach has 1 relationships.
#
# Lisa Oliver has 1 relationships.
#
# Michael Turner has 3 relationships.
#
# Joseph Castillo has 1 relationships.
#
# Jennifer Griffin has 2 relationships.
#
# Ricky Norris has 2 relationships.
#
# Gordon Graham has 1 relationships.
#
# Michelle Donovan has 2 relationships.
#
# Todd Roberts has 1 relationships.
#
# Peter Washington has 1 relationships.
#
# Mario Adams has 3 relationships.
#
# Stephanie Ortiz has 3 relationships.
#
# Mr. Joshua Bell has 2 relationships.
#
# Stephen Kelley has 2 relationships.
#
# Alexander Garcia has 4 relationships.
#
# Lauren Santiago has 2 relationships.
#
# Katherine Hoffman has 1 relationships.
#
# Laura Young has 1 relationships.
#
# Oscar Matthews has 1 relationships.
#
# Charles Escobar has 1 relationships.
#
# Jonathan Simpson has 2 relationships.
#
# Christopher Hill has 1 relationships.
#
# Chris Brown has 1 relationships.
#
# Jessica Ashley has 3 relationships.
#
# Melinda Romero has 2 relationships.
#
# Ryan Sharp has 2 relationships.
#
# Kelly Miller has 1 relationships.
#
# Rebecca Vargas has 1 relationships.
#
# Brandon Thompson has 1 relationships.
#
# Melissa Faulkner has 2 relationships.
#
# Joshua Johnson has 3 relationships.
#
# Kimberly Hall has 2 relationships.
#
# Isaiah Ellis has 1 relationships.
#
# Melissa Robinson has 2 relationships.
#
# Sylvia Young DDS has 3 relationships.
#
# Amanda Wheeler has 1 relationships.
#
# Angela Kim has 1 relationships.
#
# David Briggs has 1 relationships.
#
# Daniel King has 1 relationships.
#
# Debra Wilson has 1 relationships.
#
# Tracy Caldwell has 1 relationships.
#
# Wendy Brewer has 1 relationships.
#
# Jesse Martin has 4 relationships.
#
# Michael Smith has 2 relationships.
#
# Kelly Thompson has 1 relationships.
#
# Kevin Garcia has 4 relationships.
#
# Dr. Billy Washington has 3 relationships.
#
# Jessica Craig has 1 relationships.
#
# Sheila Goodman has 2 relationships.
#
# Samantha Alvarez has 3 relationships.
#
# Janet Robinson has 1 relationships.
#
# Mr. Jerry Martinez has 1 relationships.
#
# Daniel Matthews has 2 relationships.
#
# Hannah Lynch has 1 relationships.
#
# Shane Gill has 1 relationships.
#
# Michael Martin has 1 relationships.
#
# Samuel Pratt has 2 relationships.
#
# Kathleen Petersen has 1 relationships.
#
# Kenneth Evans has 1 relationships.
#
# Lisa Sandoval has 1 relationships.
#
# Mr. Thomas Warren has 1 relationships.
#
# Ms. Rhonda Gray has 1 relationships.
#
# Dawn Delgado has 1 relationships.
#
# Dr. Matthew Campbell has 2 relationships.
#
# Lynn Jones has 1 relationships.
#
# Emma Perry has 2 relationships.
#
# Melissa Martin has 1 relationships.
#
# Sarah Thomas has 4 relationships.
#
# Lynn Koch has 1 relationships.
#
# Robert George has 2 relationships.
#
# James Case has 4 relationships.
#
# Carolyn Ballard has 1 relationships.
#
# Diana Silva has 1 relationships.
#
# Tanner West has 3 relationships.
#
# Ashley Rivera has 2 relationships.
#
# Robert Diaz has 2 relationships.
#
# Christine Benson has 2 relationships.
#
# Edwin Ochoa has 1 relationships.
#
# Kevin Scott has 2 relationships.
#
# Samantha Padilla has 3 relationships.
#
# Rebecca Gilbert has 2 relationships.
#
# Teresa Rosales has 1 relationships.
#
# Lorraine Snyder has 4 relationships.
#
# Jacqueline Morris has 1 relationships.
#
# Jason Scott has 1 relationships.
#
# Christopher Young has 2 relationships.
#
# Michelle Kennedy has 2 relationships.
#
# Maria Shepard has 3 relationships.
#
# Candace Lewis has 1 relationships.
#
# John Murillo has 1 relationships.
#
# Seth Obrien has 1 relationships.
#
# Cheryl Davis has 1 relationships.
#
# Kristina Gutierrez has 2 relationships.
#
# Andrew James has 1 relationships.
#
# Michael Andrews has 1 relationships.
#
# Michael Rowe has 2 relationships.
#
# Johnny Daniel has 3 relationships.
#
# Julie Briggs has 1 relationships.
#
# Mark White has 3 relationships.
#
# Richard Vasquez has 2 relationships.
#
# William Guerrero has 2 relationships.
#
# Marvin Johnson has 1 relationships.
#
# Brandon Guzman has 3 relationships.
#
# Heather Taylor has 2 relationships.
#
# Rachel Jackson has 4 relationships.
#
# Dawn Douglas has 2 relationships.
#
# Randall Park has 1 relationships.
#
# Bryan Hughes has 1 relationships.
#
# Michael Martin has 1 relationships.
#
# Amanda Gomez has 1 relationships.
#
# Brittney Hawkins has 3 relationships.
#
# Rebecca Jimenez has 1 relationships.
#
# Ryan Aguilar has 1 relationships.
#
# Ashley Dennis has 1 relationships.
#
# Bryan Williams has 1 relationships.
#
# Terry Smith has 5 relationships.
#
# Donna Jones has 1 relationships.
#
# Sarah Morgan has 2 relationships.
#
# Amanda Meadows has 1 relationships.
#
# Michelle Larsen has 1 relationships.
#
# Benjamin Johnston has 1 relationships.
#
# Katherine Levy has 3 relationships.
#
# Natalie Williams has 1 relationships.
#
# Tracy White has 1 relationships.
#
# Lisa Velez has 3 relationships.
#
# Ralph Davis has 1 relationships.
#
# Samuel Vaughan has 1 relationships.
#
# Valerie Adams has 1 relationships.
#
# Benjamin Simmons has 2 relationships.
#
# Matthew Martin PhD has 1 relationships.
#
# James Sanchez has 2 relationships.
#
# Susan Leonard has 2 relationships.
#
# Erica Jones has 1 relationships.
#
# Richard Wagner has 1 relationships.
#
# Amanda Campbell has 2 relationships.
#
# Matthew Bell has 1 relationships.
#
# Adam Stephens has 1 relationships.
#
# Miss Maria Gibson has 1 relationships.
#
# Daniel Riley MD has 1 relationships.
#
# Peter Adams has 1 relationships.
#
# Dr. Bridget Holloway DDS has 1 relationships.
#
# Devin Williams has 4 relationships.
#
# Margaret Scott has 1 relationships.
#
# Aaron Stokes has 2 relationships.
#
# Ryan Patterson has 3 relationships.
#
# Rebecca Horn has 2 relationships.
#
# Samantha King has 1 relationships.
#
# Emily Gonzalez has 1 relationships.
#
# Maria Small has 2 relationships.
#
# Eileen Smith has 4 relationships.
#
# Angelica Wilson has 2 relationships.
#
# Jason Marsh has 1 relationships.
#
# Marc Molina has 1 relationships.
#
# Linda Allen has 1 relationships.
#
# Jasmine Miller has 2 relationships.
#
# Travis Shields has 2 relationships.
#
# Cheryl Rich has 2 relationships.
#
# Vanessa Watson has 1 relationships.
#
# Sarah Williams has 1 relationships.
#
# Dean Johnson has 2 relationships.
#
# Steven Klein has 2 relationships.
#
# Kyle Brennan has 1 relationships.
#
# Kaitlin Mcguire has 1 relationships.
#
# Edward Barnes has 1 relationships.
#
# Allison Thompson has 2 relationships.
#
# Patricia Mathews has 1 relationships.
#
# Edward Thompson has 2 relationships.
#
# William Taylor has 1 relationships.
#
# Daniel Joyce has 2 relationships.
#
# Jonathan Larson DDS has 2 relationships.
#
# Mark Perez has 2 relationships.
#
# Amy Jordan has 3 relationships.
#
# Bobby Bright has 3 relationships.
#
# Allison King has 1 relationships.
#
# Kaitlyn Hanson has 3 relationships.
#
# James Conner has 2 relationships.
#
# Joanna Anderson has 1 relationships.
#
# Justin Ward has 2 relationships.
#
# Holly Taylor has 1 relationships.
#
# Jeffrey Riley has 1 relationships.
#
# Haley Porter has 2 relationships.
#
# Sally Williams has 2 relationships.
#
# Emily Parker has 1 relationships.
#
# William Murphy has 2 relationships.
#
# Jerome Monroe has 1 relationships.
#
# Marissa Lester has 1 relationships.
#
# Andrea Guzman PhD has 3 relationships.
#
# Linda Harrison has 3 relationships.
#
# William Barrera MD has 2 relationships.
#
# Teresa Collins has 1 relationships.
#
# Mr. Eric Johnson has 2 relationships.
#
# Alexa Brady has 1 relationships.
#
# Jessica Wallace has 1 relationships.
#
# Anna Cochran has 2 relationships.
#
# Yolanda King has 1 relationships.
#
# Julie Peterson has 1 relationships.
#
# Benjamin Jones has 1 relationships.
#
# Steven Blackburn has 1 relationships.
#
# Mary Espinoza has 2 relationships.
#
# Jason Salinas has 1 relationships.
#
# Stephanie Salazar has 2 relationships.
#
# Sydney House has 2 relationships.
#
# Jessica Evans has 1 relationships.
#
# Bill Moreno has 4 relationships.
#
# Johnathan Payne has 2 relationships.
#
# Elizabeth Jones has 2 relationships.
#
# Linda Cook has 2 relationships.
#
# Amanda Simmons has 2 relationships.
#
# Katelyn Mooney has 2 relationships.
#
# Kristen Lee has 2 relationships.
#
# Christopher Mahoney has 3 relationships.
#
# Dylan Sweeney has 1 relationships.
#
# Brooke Martin has 3 relationships.
#
# Amy Campbell has 1 relationships.
#
# Matthew Butler has 1 relationships.
#
# Joshua Mendez has 1 relationships.
#
# Mrs. Ashley Bartlett DVM has 1 relationships.
#
# Michelle Wright has 2 relationships.
#
# William Kelly has 2 relationships.
#
# Melissa Martin has 1 relationships.
#
# Mark Colon has 1 relationships.
#
# Andrew Allen has 1 relationships.
#
# Tanya Hensley has 3 relationships.
#
# Kevin Davis has 1 relationships.
#
# Mrs. Lisa Griffith MD has 2 relationships.
#
# Jesse Wells has 1 relationships.
#
# Jacob Sutton has 3 relationships.
#
# Jacqueline Martin has 1 relationships.
#
# Kyle Figueroa has 1 relationships.

# %% [markdown]
# ### Challenge: Write a CSV file
#
# **This challenge isn't for extra marks, it's an opportunity for you to engage in some self guided discovery, only if you feel like it, and only if you have time.**
#
# If you want to challenge yourself, alter the report so that it conforms with the `.csv` file type. There are a number of ways to do this, you can use the `Pandas` module, the `csv` module, or manually.
